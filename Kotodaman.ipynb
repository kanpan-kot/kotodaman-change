# %%
gojuon = ['あ','い','う','え','お','か','き','く','け','こ','さ','し','す','せ','そ','た','ち','つ','て','と','な','に','ぬ','ね','の','は','ひ','ふ','へ','ほ','ま','み','む','め','も','や','ゆ','よ','ら','り','る','れ','ろ','わ','ん']

change1 = 1
change2 = 3
change3 = 5
change4 = 7
change5 = 12
change6 = 24

# %%
while(1):
  before_change= input()
  if before_change == 'f':
    print('終了しますか? [y/n]')
    flg = input()
    if flg == 'y':
      break
  for i in range(len(gojuon)):
    if gojuon[i] == before_change:
      print(before_change)
      print(str(change5) + '文字先:' + gojuon[(i+change5)%len(gojuon)])
      print(str(change6) + '文字先:' + gojuon[(i+change6)%len(gojuon)])
      break
    else:
      if i == len(gojuon)-1:
        print('五十音を入力してください。')
        break
# Out:
# あ
# あ
# 12文字先:す
# 24文字先:の
# か
# か
# 12文字先:つ
# 24文字先:ほ
# l
# 五十音を入力してください。
# f
# 終了しますか? [y/n]
# y
